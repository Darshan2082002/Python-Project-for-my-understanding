# %%
def hello():
    print("Hello")

message=hello
message()
# Out:
# Hello

# %%
def hello(func):
    def inner():
        print("Start")
        func()
    return inner

def h1():
    print("Darshan")

obj=hello(h1)

obj()
# Out:
# Start
# Darshan

# %% [markdown]
# Example 2

# %%
def who():
    print("Darshan")

def hello(func):
    def inner():
        print(" The current user:",end=" ")
        func()
    return inner

obj=hello(who)
obj()
# Out:
#  The current user: Darshan

# %% [markdown]
# Decorator

# %%
# @is the decorator symbol 

def hello(func):
    def inner():
        print(" The current user:",end=" ")
        func()
    return inner
@hello    
def who():
    print("Darshan")


obj=who
obj()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 14
#      10     print("Darshan")
#      13 obj=who
# ---> 14 obj()
#
# TypeError: 'NoneType' object is not callable
