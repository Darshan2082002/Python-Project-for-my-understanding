# %%
def leap(n):
    if (n%400==0)or(n%4==0 and n%100!=0):
        return("Schedule event")
    return("Not to schedule event")

leap(2025)
# Out:
# 'Not to schedule event'

# %%
from regex import T


def car_rental(R1,T1,R2,T2):
    T3=T2//60
    T=T3-T1
    r=R1*T1+ R2*T
    return r
R1=int(input())
T1=int(input())
R2=int(input())
T2=int(input())

car_rental(R1,T1,R2,T2)
# Out:
# 120
