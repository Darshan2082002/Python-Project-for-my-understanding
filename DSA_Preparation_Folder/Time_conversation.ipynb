# %%
def time_converstaion(x,y):
    c=x*y
    r=c%12
    if r==0:
        return 12
    else:
        return r
time_converstaion(12,13)
# Out:
# 0

# %%
my=[2,3,4,5]
arr=[4,5,6]
for i in my:
    for j in arr:
       print( time_converstaion(i,j))
# Out:
# 8
# 10
# 0
# 0
# 3
# 6
# 4
# 8
# 0
# 8
# 1
# 6
