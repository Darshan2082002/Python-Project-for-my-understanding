# %%
a=int(input("Enter the input for Dollar 1"))
b=int(input("Enter the input for cent 1"))
c=int(input("Enter the input for Dollar 2"))
d=int(input("Enter the inpit for cent 2"))
e=a+c
f=b+d
dollar=e+(c//100)
cent=f%100
print(dollar)
print(cent)
# Out:
# 241
# 33
