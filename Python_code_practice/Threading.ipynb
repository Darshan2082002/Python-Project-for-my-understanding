# %%
from asyncio import threads
import threading 
import time 

def crawl(link,delay=3):
    print(f"crawl started for{link}")
    time.sleep(delay)
    print(f"crawl ended for{link}")
links=[
    "https://python.org",
    "https://docs.python.org",
    "https://peps.python.org",
    ]
threads=[]
for link in links:
    t=threading.Thread(target=crawl,args=(link,),kwargs={"delay":2})
    threads.append(t)
for t in threads:
    t.start()
for t in threads:
    t.join()
# Out:
# crawl started forhttps://python.org
# crawl started forhttps://docs.python.org
# crawl started forhttps://peps.python.org
# crawl ended forhttps://python.org
# crawl ended forhttps://peps.python.org
# crawl ended forhttps://docs.python.org
