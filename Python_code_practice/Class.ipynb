# %%
class Dog:
    species=' Dog'
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def description(self):
        return f"{self.name} is {self.age} years old"
    def speak(self,sound):
        return f"{self.name} says{"   ",sound}"

# %%
model=Dog("Black",4)
print(model.description())
model.speak("wooo")
# Out:
# Blackis4 years old
# 'Black sayswooo'

# %%
# Practice session 
class car:
    def __init__(self,color,mileage):
        self.color=color
        self.mileage=mileage
    def description(self):
        return f" The {self.color} car has {self.mileage} miles"

# %%
c=car("blue",20000)
print(c.description())
# Out:
#  The blue car has 20000 miles

# %%
## Inhertiance 
class parent:
    hair="brown color"
class child(parent):
    pass

# %%
c=child()
print(c)
# Out:
# <__main__.child object at 0x0000022241EE20D0>

# %%
class Dog:
    species = "Canis familiaris"

    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __str__(self):
        return f"{self.name} is {self.age} years old"

    def speak(self, sound):
        return f"{self.name} says {sound}"
class JackRussellTerrier(Dog):
    pass

class Dachshund(Dog):
    pass

class Bulldog(Dachshund):
    pass

# %%
miles = JackRussellTerrier("Miles", 4)
buddy = Dachshund("Buddy", 9)
jack = Bulldog("Jack", 3)
jim = Bulldog("Jim", 5)

# %%
print(jack)
# Out:
# Jack is 3 years old

# %%
print(jim
      )
# Out:
# Jim is 5 years old

# %%
print(buddy)
# Out:
# Buddy is 9 years old

# %%
jim.speak("Woow")
# Out:
# 'Jim says Woow'
